# %%
import stdflow as sf
from stdflow import StepRunner, Pipeline

countries = sf.var('countries', ['spain', 'italy'])

ppl = Pipeline()

for country in countries:
    ppl.add_step("process_sex.ipynb", variables={"country": country})
    ppl.add_step("process_tweets.ipynb", variables={"country": country})
ppl
# Out:
# ...
#             PIPELINE
# ...
#
# STEP 1
# 	path: process_sex.ipynb
# 	vars: {'country': 'spain'}
#
# STEP 2
# 	path: process_tweets.ipynb
# 	vars: {'country': 'spain'}
#
# STEP 3
# 	path: process_sex.ipynb
# 	vars: {'country': 'italy'}
#
# STEP 4
# 	path: process_tweets.ipynb
# 	vars: {'country': 'italy'}
#
# ...

# %%
ppl.run(progress_bar=False)
# Out:
# ...
#     01.             process_sex.ipynb
# ...
# Variables: {'country': 'spain'}
# Error executing the notebook: process_sex.ipynb
# ---------------------------------------------------------------------------
# CellExecutionError                        Traceback (most recent call last)
# /var/folders/vx/nb16bg2j51n_8nts6_s9_l540000gn/T/ipykernel_23087/659061761.py in <module>
# ----> 1 ppl.run(progress_bar=False)
#
# ~/Documents/artefact/stdflow/stdflow/pipeline.py in run(self, progress_bar, **kwargs)
#      61             print(f"Variables: {step.env_vars}")
#      62             # Run step
# ---> 63             step.run(**kwargs)
#      64
#      65             print("", end="\n\n")
#
# ~/Documents/artefact/stdflow/stdflow/step_runner.py in run(self, **kwargs)
#     103                 raise ValueError(f"extension {extension} not supported")
#     104         except Exception as e:
# --> 105             raise e
#     106         finally:
#     107             self.env.end_run()
#
# ...

# %% [raw]
# ---
# description: Test
# output-file: nbdev_broken.html
# title: Test
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import nbdev
nbdev.__version__
# Out:
# '2.3.12'

# %%
import sys

# %%
sys.version
# Out:
# '3.7.16 (default, Jan 17 2023, 09:28:58) \n[Clang 14.0.6 ]'

# %%
#| echo: false
#| output: asis
show_doc(super_func)
# Out:
# ---
#
# ### super_func
#
# >      super_func (keyword_or_non_keyword_arg, keyword_only_arg)
#
# super func
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | keyword_or_non_keyword_arg |  | this is a keyword or non-keyword arg |
# | keyword_only_arg |  |  |
# | **Returns** | **str** | **return string** |

# %%
super_func(1, keyword_only_arg=2)

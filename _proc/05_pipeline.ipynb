# %% [raw]
# ---
# description: 'Pipeline class using Notebooks as steps with StepRunner. see: [StepRunner]()'
# output-file: pipeline.html
# title: Pipeline
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Pipeline)
# Out:
# ---
#
# [source](https://github.com/CyprienRicque/stdflow/blob/main/stdflow/pipeline.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pipeline
#
# >      Pipeline (steps:List[StepRunner]|StepRunner=None, *args)
#
# Create pipeline of notebooks with optional variables

# %%
#| echo: false
#| output: asis
show_doc(Pipeline.add_step)
# Out:
# ---
#
# [source](https://github.com/CyprienRicque/stdflow/blob/main/stdflow/pipeline.py#L49){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pipeline.add_step
#
# >      Pipeline.add_step (step:Union[stdflow.step_runner.StepRunner,str]=None,
# >                         **kwargs)
#
# Add step to pipeline
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | step | StepRunner \| str | None | StepRunner or path to notebook |
# | kwargs |  |  |  |

# %%
#| echo: false
#| output: asis
show_doc(Pipeline.verify)
# Out:
# ---
#
# [source](https://github.com/CyprienRicque/stdflow/blob/main/stdflow/pipeline.py#L42){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pipeline.verify
#
# >      Pipeline.verify ()
#
# Verify that all steps are valid

# %%
#| echo: false
#| output: asis
show_doc(Pipeline.run)
# Out:
# ---
#
# [source](https://github.com/CyprienRicque/stdflow/blob/main/stdflow/pipeline.py#L61){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pipeline.run
#
# >      Pipeline.run (save_notebook:bool=False, progress_bar:bool=False, kernel:U
# >                    nion[typing_extensions.Literal[':current',':target',':any_a
# >                    vailable'],str]=':target',
# >                    kernels_on_fail:Union[str,list]=None, verbose=True,
# >                    **kwargs)
#
# Run pipeline
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | save_notebook | bool | False | Saves the output of cells in the notebook if True (default: False) |
# | progress_bar | bool | False | Whether to show progress bar |
# | kernel | Literal[(':current', ':target', ':any_available')] \| str | :target | kernel name or :current to use current kernel, :target to use kernel specified in metadata of target notebook, :any_available to use any available kernel. |
# | kernels_on_fail | str \| list | None | kernels to try if `kernel` does not exist / is not available (default: [":current", "python", ":any_available"]) |
# | verbose | bool | True | Whether to print output of cells |
# | kwargs |  |  |  |

# %%
#| echo: false
#| output: asis
show_doc(Pipeline.__call__)
# Out:
# ---
#
# [source](https://github.com/CyprienRicque/stdflow/blob/main/stdflow/pipeline.py#L114){target="_blank" style="float:right; font-size:smaller"}
#
# ### Pipeline.__call__
#
# >      Pipeline.__call__ (progress_bar:bool=False, **kwargs)
#
# Run pipeline
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | progress_bar | bool | False | Whether to show progress bar |
# | kwargs |  |  |  |
